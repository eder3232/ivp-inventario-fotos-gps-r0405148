# %% [markdown]
# # Procesamiento de datos

# %% [markdown]
# En este archivo se verifica que los datos tomados en campo sean consistentes con las imagenes tomadas en campo.

# %% [markdown]
# ## Importaciones necesarias

# %%
import shutil
import os
import glob

import pandas as pd
import numpy as np
from IPython.display import display, HTML
from config import CONFIG
from pathlib import Path

# %% [markdown]
# ## Paths necesarios

# %%
excel_path=Path(CONFIG["EXEL_PATH"])
coordenadas_path=Path(CONFIG["COORDENADAS_PATH"])

processed_data_pickle_path=Path(CONFIG["PROCESSED_DATA_PICKLE_PATH"])
images_renamed_by_date_dir=Path(CONFIG["IMAGES_RENAMED_BY_DATE_DIR"])
images_processed_dir=Path(CONFIG["IMAGES_PROCESSED_DIR"])

# %% [markdown]
# ## Importación de los datos

# %% [markdown]
# ### Importación de los datos de campo

# %%
df=pd.read_excel(excel_path,dtype=str,keep_default_na=False)

# %%
df["id"] = pd.to_numeric(df["id"], errors="coerce").astype("Int64")

# df["m"]  = pd.to_numeric(df["m"], errors="coerce").astype("Int64")

# %% [markdown]
# ### Importación de las coordenadas del gps

# %%
df_gps=pd.read_excel(coordenadas_path,dtype=str,keep_default_na=False)

# %%
df_gps["x"] = pd.to_numeric(df_gps["x"], errors="coerce").astype("Int64")
df_gps["y"] = pd.to_numeric(df_gps["y"], errors="coerce").astype("Int64")
df_gps["zona"] = pd.to_numeric(df_gps["zona"], errors="coerce").astype("Int64")

# %%
df_gps.head()
# Out:
#         x        y  zona
# 0  189967  8229889    19
# 1  189968  8229891    19
# 2  190139  8227888    19
# 3  190105  8227713    19
# 4  190092  8227457    19

# %% [markdown]
# Conviertiendo el campo fotos-number y fotos-gps de string a listas

# %%
def convertir_a_lista(cadena):
    # Si el valor es NaN, None o cadena vacía, retornamos lista vacía
    if pd.isnull(cadena) or cadena.strip() == '':
        return []
    # Dividimos por '-' y convertimos cada elemento a int si corresponde
    return [int(x) for x in cadena.split('-') if x.isdigit()]

# Aplicamos la función a ambas columnas
df['foto-number'] = df['foto-number'].apply(convertir_a_lista)
df['foto-gps']    = df['foto-gps'].apply(convertir_a_lista)

# %%
df.head(10)
# Out:
#    id tipo     descripcion informacion-adicional km m sentido   foto-number  \
# 0   1                  fin                                  u           [1]
# 1   2         alcantarilla                                  u     [2, 3, 4]
# 2   3                baden                                  u           [6]
# 3   4         alcantarilla                                  u     [7, 8, 9]
# 4   5         alcantarilla                                  u      [11, 12]
# 5   6    a  señal de baden                                  o          [14]
# 6   7                baden                                  u          [16]
# 7   8    a  señal de baden                                  i          [18]
# 8   9    a           curva                                  o          [20]
# 9  10         alcantarilla                                  u  [22, 23, 24]
#
#   foto-gps observacion observacion-detalles observacion-gabinete
# 0       []
# 1      [5]
# 2      [7]                                       foto 7 repetida
# 3     [10]
# 4     [13]
# 5     [15]
# 6     [17]
# 7     [19]
# 8     [21]
# 9     [25]

# %% [markdown]
# ## Edición manual de datos

# %% [markdown]
# Se van a editar los registros

# %% [markdown]
# ### El indice 7 de fotos esta repetida, hay que cambiarlo

# %%
# Asignar la foto-gps = [2] al primer registro
df.at[0, 'foto-gps'] = [2]

# Incrementar en 1 los valores de 'foto-number' y 'foto-gps' en las filas siguientes
for i in range(1, len(df)):
    df.at[i, 'foto-number'] = [x + 1 for x in df.at[i, 'foto-number']]
    df.at[i, 'foto-gps']    = [x + 1 for x in df.at[i, 'foto-gps']]

# %%
df.head(10)
# Out:
#    id tipo     descripcion informacion-adicional km m sentido   foto-number  \
# 0   1                  fin                                  u           [1]
# 1   2         alcantarilla                                  u     [3, 4, 5]
# 2   3                baden                                  u           [7]
# 3   4         alcantarilla                                  u    [8, 9, 10]
# 4   5         alcantarilla                                  u      [12, 13]
# 5   6    a  señal de baden                                  o          [15]
# 6   7                baden                                  u          [17]
# 7   8    a  señal de baden                                  i          [19]
# 8   9    a           curva                                  o          [21]
# 9  10         alcantarilla                                  u  [23, 24, 25]
#
#   foto-gps observacion observacion-detalles observacion-gabinete
# 0      [2]
# 1      [6]
# 2      [8]                                       foto 7 repetida
# 3     [11]
# 4     [14]
# 5     [16]
# 6     [18]
# 7     [20]
# 8     [22]
# 9     [26]

# %% [markdown]
# La foto numero 8 esta repetida, hay que hacer saltar uno

# %%
# 1) Creamos una máscara para filtrar los registros desde id=4 en adelante
mask = df['id'] >= 4

# 2) A todos los registros que cumplan la máscara, les incrementamos en +1 
#    cada valor de foto-number y foto-gps.
df.loc[mask, 'foto-number'] = df.loc[mask, 'foto-number'].apply(
    lambda lista_fotos: [x + 1 for x in lista_fotos]
)
df.loc[mask, 'foto-gps'] = df.loc[mask, 'foto-gps'].apply(
    lambda lista_fotos: [x + 1 for x in lista_fotos]
)

# %%
df.head(10)
# Out:
#    id tipo     descripcion informacion-adicional km m sentido   foto-number  \
# 0   1                  fin                                  u           [1]
# 1   2         alcantarilla                                  u     [3, 4, 5]
# 2   3                baden                                  u           [7]
# 3   4         alcantarilla                                  u   [9, 10, 11]
# 4   5         alcantarilla                                  u      [13, 14]
# 5   6    a  señal de baden                                  o          [16]
# 6   7                baden                                  u          [18]
# 7   8    a  señal de baden                                  i          [20]
# 8   9    a           curva                                  o          [22]
# 9  10         alcantarilla                                  u  [24, 25, 26]
#
#   foto-gps observacion observacion-detalles observacion-gabinete
# 0      [2]
# 1      [6]
# 2      [8]                                       foto 7 repetida
# 3     [12]
# 4     [15]
# 5     [17]
# 6     [19]
# 7     [21]
# 8     [23]
# 9     [27]

# %% [markdown]
# Existe un error similar en la foto 70

# %%
df.iloc[20:30]
# Out:
#     id tipo                      descripcion informacion-adicional km m  \
# 20  21       curva y contracurva pronunciada
# 21  22                          alcantarilla
# 22  23                          alcantarilla
# 23  24                          alcantarilla
# 24  25                            curva en u
# 25  26                          alcantarilla
# 26  27                            curva en u
# 27  28       curva y contracurva pronunciada
# 28  29                            curva en u
# 29  30                            curva en u
#
#    sentido   foto-number foto-gps       observacion observacion-detalles  \
# 20                  [58]     [59]  deterioro severo        señal borrada
# 21       u  [60, 61, 62]     [63]
# 22       u      [64, 65]     [66]
# 23       u  [67, 68, 69]     [70]
# 24       o          [71]     [72]
# 25       u      [72, 73]     [74]
# 26       i          [75]     [76]
# 27       i          [77]     [78]
# 28       o          [79]     [80]
# 29       o          [81]     [82]
#
#    observacion-gabinete
# 20
# 21
# 22
# 23
# 24
# 25     foto 70 repetida
# 26
# 27
# 28
# 29

# %%
# 1) Creamos una máscara para filtrar los registros desde id=4 en adelante
mask = df['id'] >= 26
# 2) A todos los registros que cumplan la máscara, les incrementamos en +1 
#    cada valor de foto-number y foto-gps.
df.loc[mask, 'foto-number'] = df.loc[mask, 'foto-number'].apply(
    lambda lista_fotos: [x + 1 for x in lista_fotos]
)
df.loc[mask, 'foto-gps'] = df.loc[mask, 'foto-gps'].apply(
    lambda lista_fotos: [x + 1 for x in lista_fotos]
)

# %%
df.iloc[20:30]
# Out:
#     id tipo                      descripcion informacion-adicional km m  \
# 20  21       curva y contracurva pronunciada
# 21  22                          alcantarilla
# 22  23                          alcantarilla
# 23  24                          alcantarilla
# 24  25                            curva en u
# 25  26                          alcantarilla
# 26  27                            curva en u
# 27  28       curva y contracurva pronunciada
# 28  29                            curva en u
# 29  30                            curva en u
#
#    sentido   foto-number foto-gps       observacion observacion-detalles  \
# 20                  [58]     [59]  deterioro severo        señal borrada
# 21       u  [60, 61, 62]     [63]
# 22       u      [64, 65]     [66]
# 23       u  [67, 68, 69]     [70]
# 24       o          [71]     [72]
# 25       u      [73, 74]     [75]
# 26       i          [76]     [77]
# 27       i          [78]     [79]
# 28       o          [80]     [81]
# 29       o          [82]     [83]
#
#    observacion-gabinete
# 20
# 21
# 22
# 23
# 24
# 25     foto 70 repetida
# 26
# 27
# 28
# 29

# %%
df.tail()
# Out:
#     id tipo                      descripcion informacion-adicional km m  \
# 30  31                            curva en u
# 31  32                          alcantarilla
# 32  33       curva y contracurva pronunciada
# 33  34                       cruce de ganado
# 34  35                                inicio
#
#    sentido   foto-number foto-gps observacion observacion-detalles  \
# 30       i          [84]     [85]
# 31       u  [86, 87, 88]     [89]
# 32       i          [90]     [91]
# 33       i          [91]     [93]
# 34                  [94]     [95]
#
#    observacion-gabinete
# 30
# 31
# 32
# 33
# 34

# %% [markdown]
# eliminamos el registro con el id 17

# %%
def remove_record_and_shift(df, id_to_remove):
    """
    Elimina el registro con id == id_to_remove y
    'desplaza' la numeración de fotos de los registros siguientes.
    Retorna un nuevo DataFrame con las correcciones aplicadas.
    """
    
    # 1) Hallar la(s) fila(s) que coincidan con el id a eliminar
    row_index = df.index[df['id'] == id_to_remove]
    if len(row_index) == 0:
        print(f"No se encontró ningún registro con id={id_to_remove}.")
        return df  # No hay cambios
    
    # 2) Calcular cuántas fotos tenía ese registro (suma de ambas columnas)
    idx = row_index[0]  # Tomamos la primera coincidencia
    fotos_en_registro = len(df.at[idx, 'foto-number']) + len(df.at[idx, 'foto-gps'])
    
    # 3) Eliminar ese registro
    df = df.drop(idx)
    
    # 4) 'Desplazar' la numeración de las fotos en los registros con id > id_to_remove
    mask = df['id'] > id_to_remove
    
    # Para cada lista de foto-number y foto-gps en filas posteriores, restar fotos_en_registro
    df.loc[mask, 'foto-number'] = df.loc[mask, 'foto-number'].apply(
        lambda lista_fotos: [num - fotos_en_registro for num in lista_fotos]
    )
    df.loc[mask, 'foto-gps'] = df.loc[mask, 'foto-gps'].apply(
        lambda lista_fotos: [num - fotos_en_registro for num in lista_fotos]
    )
    
    return df

# %%
df = remove_record_and_shift(df, 31)

# %% [markdown]
# Renombrando el registro 17

# %%
df.loc[df['id'] == 17, 'descripcion'] = 'señal de puente angosto'

# %% [markdown]
# El registro numero dice que tiene 3 fotos, pero en realidad se tomaron solo 2 en campo

# %%
def ajustar_fotos_registro(*, id, fotos_dataframe, fotos_reales, df):
    """
    Corrige la numeración de fotos de un registro específico y ajusta los
    registros siguientes en el DataFrame.
    
    Parámetros:
      - id: Identificador del registro a corregir (columna 'id').
      - fotos_dataframe: Número de fotos (enteros consecutivos) que figura en 'foto-number'
                         para ese registro.
      - fotos_reales: Número real de fotos que se tomaron en campo para ese registro.
      - df: DataFrame de pandas que contiene la información.
    
    La función ajusta:
      - La lista en 'foto-number' del registro: si hay de más se elimina de la derecha;
        si hay de menos se añaden números consecutivos.
      - La lista en 'foto-gps' del registro: se le resta la diferencia.
      - En todos los registros con 'id' mayor, se ajusta la numeración (se restan o suman la diferencia)
        en ambas columnas ('foto-number' y 'foto-gps').
    
    Retorna el DataFrame modificado.
    """
    # Buscar la fila correspondiente al registro con el id indicado
    indices = df.index[df['id'] == id].tolist()
    if not indices:
        print(f"No se encontró ningún registro con id={id}.")
        return df  # Sin cambios si no se encuentra
    idx = indices[0]
    
    # Calcular la diferencia: (número según DataFrame) - (número real tomado en campo)
    diferencia = fotos_dataframe - fotos_reales
    
    # Ajustar la columna 'foto-number' del registro
    lista_actual = df.at[idx, 'foto-number']  # se asume que es una lista de enteros
    if diferencia > 0:
        # Si hay de más, eliminamos de la derecha (se asume que son consecutivos)
        nueva_lista = lista_actual[:fotos_reales]
    elif diferencia < 0:
        # Si hay de menos, agregamos números consecutivos al final
        if lista_actual:
            ultimo = lista_actual[-1]
        else:
            # En caso de lista vacía, asumimos inicio arbitrario (por ejemplo 1)
            ultimo = 0
        # Agregar tantos números consecutivos como haga falta
        nuevos_numeros = list(range(ultimo + 1, ultimo + 1 + abs(diferencia)))
        nueva_lista = lista_actual + nuevos_numeros
    else:
        # Sin diferencia: no se cambia nada
        nueva_lista = lista_actual
    # Actualizamos el registro
    df.at[idx, 'foto-number'] = nueva_lista
    
    # Ajustar el campo 'foto-gps' del registro, restándole la diferencia a cada número
    lista_gps = df.at[idx, 'foto-gps']
    df.at[idx, 'foto-gps'] = [num - diferencia for num in lista_gps]
    
    # Ahora, para todos los registros con id mayor al del registro corregido, ajustar ambas columnas.
    mask = df['id'] > id
    df.loc[mask, 'foto-number'] = df.loc[mask, 'foto-number'].apply(
        lambda lst: [num - diferencia for num in lst]
    )
    df.loc[mask, 'foto-gps'] = df.loc[mask, 'foto-gps'].apply(
        lambda lst: [num - diferencia for num in lst]
    )
    
    return df

# %%
df = ajustar_fotos_registro(id=24, fotos_dataframe=3, fotos_reales=2, df=df)

# %% [markdown]
# Visualizamos toda la data:

# %%
html = df.to_html()
display(HTML(html))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>tipo</th>
#       <th>descripcion</th>
#       <th>informacion-adicional</th>
#       <th>km</th>
#       <th>m</th>
#       <th>sentido</th>
#       <th>foto-number</th>
#       <th>foto-gps</th>
#       <th>observacion</th>
#       <th>observacion-detalles</th>
#       <th>observacion-gabinete</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td></td>
#       <td>fin</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[1]</td>
#       <td>[2]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[3, 4, 5]</td>
#       <td>[6]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td></td>
#       <td>baden</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[7]</td>
#       <td>[8]</td>
#       <td></td>
#       <td></td>
#       <td>foto 7 repetida</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[9, 10, 11]</td>
#       <td>[12]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[13, 14]</td>
#       <td>[15]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>a</td>
#       <td>señal de baden</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>o</td>
#       <td>[16]</td>
#       <td>[17]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td></td>
#       <td>baden</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[18]</td>
#       <td>[19]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>a</td>
#       <td>señal de baden</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>i</td>
#       <td>[20]</td>
#       <td>[21]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>a</td>
#       <td>curva</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>o</td>
#       <td>[22]</td>
#       <td>[23]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[24, 25, 26]</td>
#       <td>[27]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>11</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[28, 29]</td>
#       <td>[30]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>12</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[31, 32]</td>
#       <td>[33]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[34, 35, 36]</td>
#       <td>[37]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>14</td>
#       <td></td>
#       <td>curva y contracurva pronunciada</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>[38]</td>
#       <td>[39]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>15</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[40, 41, 42]</td>
#       <td>[43]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>16</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[44, 45, 46]</td>
#       <td>[47]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>17</td>
#       <td>a</td>
#       <td>señal de puente angosto</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>[48]</td>
#       <td>[49]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>18</td>
#       <td></td>
#       <td>puente</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[50]</td>
#       <td>[51]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>19</td>
#       <td></td>
#       <td>señal de puente angosto</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>i</td>
#       <td>[52]</td>
#       <td>[53]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>20</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[54, 55, 56]</td>
#       <td>[57]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>21</td>
#       <td></td>
#       <td>curva y contracurva pronunciada</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>[58]</td>
#       <td>[59]</td>
#       <td>deterioro severo</td>
#       <td>señal borrada</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>22</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[60, 61, 62]</td>
#       <td>[63]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>23</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[64, 65]</td>
#       <td>[66]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>24</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[67, 68]</td>
#       <td>[69]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>25</td>
#       <td></td>
#       <td>curva en u</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>o</td>
#       <td>[70]</td>
#       <td>[71]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>26</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[72, 73]</td>
#       <td>[74]</td>
#       <td></td>
#       <td></td>
#       <td>foto 70 repetida</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>27</td>
#       <td></td>
#       <td>curva en u</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>i</td>
#       <td>[75]</td>
#       <td>[76]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>28</td>
#       <td></td>
#       <td>curva y contracurva pronunciada</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>i</td>
#       <td>[77]</td>
#       <td>[78]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>29</td>
#       <td></td>
#       <td>curva en u</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>o</td>
#       <td>[79]</td>
#       <td>[80]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>30</td>
#       <td></td>
#       <td>curva en u</td>

# %% [markdown]
# Esta función copia las imagenes y elimina las que no son requeridas

# %%
def copiar_imagenes(origen, destino, excluir):
    """
    Copia imágenes de la carpeta 'origen' a la carpeta 'destino' ignorando aquellas cuyo nombre numérico (sin extensión)
    se encuentre en la lista 'excluir'. Las imágenes copiadas se renombrarán consecutivamente a partir de 1.
    
    Parámetros:
        origen (str): ruta de la carpeta de origen.
        destino (str): ruta de la carpeta de destino.
        excluir (list of int): lista de números a excluir.
    """
    # Verificar si el directorio de destino existe, si no, lo crea.
    if not os.path.exists(destino):
        os.makedirs(destino)
        print(f"Directorio destino creado: {destino}")

    # Definir las extensiones de imagen a copiar.
    extensiones = ('*.jpg', '*.jpeg', '*.png', '*.gif', '*.bmp', '*.tiff')
    
    # Recopilar todos los archivos de imagen de las extensiones indicadas.
    imagenes = []
    for ext in extensiones:
        imagenes.extend(glob.glob(os.path.join(origen, ext)))
    
    # Filtrar y ordenar las imágenes por el número que tienen en su nombre.
    imagenes_filtradas = []
    for ruta_imagen in imagenes:
        nombre_archivo = os.path.basename(ruta_imagen)
        nombre, extension = os.path.splitext(nombre_archivo)
        try:
            numero = int(nombre)
            if numero in excluir:
                print(f"Excluyendo imagen: {nombre_archivo}")
            else:
                imagenes_filtradas.append((numero, ruta_imagen, extension))
        except ValueError:
            print(f"El archivo {nombre_archivo} no tiene un nombre numérico y será ignorado.")
    
    # Ordena las imágenes filtradas según el número original.
    imagenes_filtradas.sort(key=lambda x: x[0])
    
    # Copia las imágenes y las renombra de forma consecutiva.
    contador = 0
    for numero_original, ruta_imagen, extension in imagenes_filtradas:
        contador += 1
        nuevo_nombre = f"{contador}{extension}"
        destino_imagen = os.path.join(destino, nuevo_nombre)
        try:
            shutil.copy(ruta_imagen, destino_imagen)
            print(f"Copiado: {ruta_imagen} como {destino_imagen}")
        except Exception as e:
            print(f"Error al copiar {ruta_imagen}: {e}")
    
    print(f"Total de imágenes copiadas: {contador}")

# Ejemplo de uso:
ruta_origen = images_renamed_by_date_dir
ruta_destino = images_processed_dir
excluir = [3]

copiar_imagenes(ruta_origen, ruta_destino, excluir)
# Out:
# Excluyendo imagen: 3.jpg
# Copiado: tmp\images\100_images_renamed_by_date\1.jpg como tmp\images\200_images_processed\1.jpg
# Copiado: tmp\images\100_images_renamed_by_date\2.jpg como tmp\images\200_images_processed\2.jpg
# Copiado: tmp\images\100_images_renamed_by_date\4.jpg como tmp\images\200_images_processed\3.jpg
# Copiado: tmp\images\100_images_renamed_by_date\5.jpg como tmp\images\200_images_processed\4.jpg
# Copiado: tmp\images\100_images_renamed_by_date\6.jpg como tmp\images\200_images_processed\5.jpg
# Copiado: tmp\images\100_images_renamed_by_date\7.jpg como tmp\images\200_images_processed\6.jpg
# Copiado: tmp\images\100_images_renamed_by_date\8.jpg como tmp\images\200_images_processed\7.jpg
# Copiado: tmp\images\100_images_renamed_by_date\9.jpg como tmp\images\200_images_processed\8.jpg
# Copiado: tmp\images\100_images_renamed_by_date\10.jpg como tmp\images\200_images_processed\9.jpg
# Copiado: tmp\images\100_images_renamed_by_date\11.jpg como tmp\images\200_images_processed\10.jpg
# Copiado: tmp\images\100_images_renamed_by_date\12.jpg como tmp\images\200_images_processed\11.jpg
# Copiado: tmp\images\100_images_renamed_by_date\13.jpg como tmp\images\200_images_processed\12.jpg
# Copiado: tmp\images\100_images_renamed_by_date\14.jpg como tmp\images\200_images_processed\13.jpg
# Copiado: tmp\images\100_images_renamed_by_date\15.jpg como tmp\images\200_images_processed\14.jpg
# Copiado: tmp\images\100_images_renamed_by_date\16.jpg como tmp\images\200_images_processed\15.jpg
# Copiado: tmp\images\100_images_renamed_by_date\17.jpg como tmp\images\200_images_processed\16.jpg
# Copiado: tmp\images\100_images_renamed_by_date\18.jpg como tmp\images\200_images_processed\17.jpg
# Copiado: tmp\images\100_images_renamed_by_date\19.jpg como tmp\images\200_images_processed\18.jpg
# Copiado: tmp\images\100_images_renamed_by_date\20.jpg como tmp\images\200_images_processed\19.jpg
# Copiado: tmp\images\100_images_renamed_by_date\21.jpg como tmp\images\200_images_processed\20.jpg
# Copiado: tmp\images\100_images_renamed_by_date\22.jpg como tmp\images\200_images_processed\21.jpg
# Copiado: tmp\images\100_images_renamed_by_date\23.jpg como tmp\images\200_images_processed\22.jpg
# Copiado: tmp\images\100_images_renamed_by_date\24.jpg como tmp\images\200_images_processed\23.jpg
# Copiado: tmp\images\100_images_renamed_by_date\25.jpg como tmp\images\200_images_processed\24.jpg
# Copiado: tmp\images\100_images_renamed_by_date\26.jpg como tmp\images\200_images_processed\25.jpg
# Copiado: tmp\images\100_images_renamed_by_date\27.jpg como tmp\images\200_images_processed\26.jpg
# Copiado: tmp\images\100_images_renamed_by_date\28.jpg como tmp\images\200_images_processed\27.jpg
# Copiado: tmp\images\100_images_renamed_by_date\29.jpg como tmp\images\200_images_processed\28.jpg
# Copiado: tmp\images\100_images_renamed_by_date\30.jpg como tmp\images\200_images_processed\29.jpg
# Copiado: tmp\images\100_images_renamed_by_date\31.jpg como tmp\images\200_images_processed\30.jpg
# Copiado: tmp\images\100_images_renamed_by_date\32.jpg como tmp\images\200_images_processed\31.jpg
# Copiado: tmp\images\100_images_renamed_by_date\33.jpg como tmp\images\200_images_processed\32.jpg
# Copiado: tmp\images\100_images_renamed_by_date\34.jpg como tmp\images\200_images_processed\33.jpg
# Copiado: tmp\images\100_images_renamed_by_date\35.jpg como tmp\images\200_images_processed\34.jpg
# Copiado: tmp\images\100_images_renamed_by_date\36.jpg como tmp\images\200_images_processed\35.jpg
# Copiado: tmp\images\100_images_renamed_by_date\37.jpg como tmp\images\200_images_processed\36.jpg
# Copiado: tmp\images\100_images_renamed_by_date\38.jpg como tmp\images\200_images_processed\37.jpg
# Copiado: tmp\images\100_images_renamed_by_date\39.jpg como tmp\images\200_images_processed\38.jpg
# Copiado: tmp\images\100_images_renamed_by_date\40.jpg como tmp\images\200_images_processed\39.jpg
# Copiado: tmp\images\100_images_renamed_by_date\41.jpg como tmp\images\200_images_processed\40.jpg
# Copiado: tmp\images\100_images_renamed_by_date\42.jpg como tmp\images\200_images_processed\41.jpg
# Copiado: tmp\images\100_images_renamed_by_date\43.jpg como tmp\images\200_images_processed\42.jpg
# Copiado: tmp\images\100_images_renamed_by_date\44.jpg como tmp\images\200_images_processed\43.jpg
# Copiado: tmp\images\100_images_renamed_by_date\45.jpg como tmp\images\200_images_processed\44.jpg
# Copiado: tmp\images\100_images_renamed_by_date\46.jpg como tmp\images\200_images_processed\45.jpg
# Copiado: tmp\images\100_images_renamed_by_date\47.jpg como tmp\images\200_images_processed\46.jpg
# Copiado: tmp\images\100_images_renamed_by_date\48.jpg como tmp\images\200_images_processed\47.jpg
# Copiado: tmp\images\100_images_renamed_by_date\49.jpg como tmp\images\200_images_processed\48.jpg
# Copiado: tmp\images\100_images_renamed_by_date\50.jpg como tmp\images\200_images_processed\49.jpg
# Copiado: tmp\images\100_images_renamed_by_date\51.jpg como tmp\images\200_images_processed\50.jpg
# Copiado: tmp\images\100_images_renamed_by_date\52.jpg como tmp\images\200_images_processed\51.jpg
# Copiado: tmp\images\100_images_renamed_by_date\53.jpg como tmp\images\200_images_processed\52.jpg
# Copiado: tmp\images\100_images_renamed_by_date\54.jpg como tmp\images\200_images_processed\53.jpg
# Copiado: tmp\images\100_images_renamed_by_date\55.jpg como tmp\images\200_images_processed\54.jpg
# Copiado: tmp\images\100_images_renamed_by_date\56.jpg como tmp\images\200_images_processed\55.jpg
# Copiado: tmp\images\100_images_renamed_by_date\57.jpg como tmp\images\200_images_processed\56.jpg
# Copiado: tmp\images\100_images_renamed_by_date\58.jpg como tmp\images\200_images_processed\57.jpg
# Copiado: tmp\images\100_images_renamed_by_date\59.jpg como tmp\images\200_images_processed\58.jpg
# Copiado: tmp\images\100_images_renamed_by_date\60.jpg como tmp\images\200_images_processed\59.jpg
# Copiado: tmp\images\100_images_renamed_by_date\61.jpg como tmp\images\200_images_processed\60.jpg
# Copiado: tmp\images\100_images_renamed_by_date\62.jpg como tmp\images\200_images_processed\61.jpg
# Copiado: tmp\images\100_images_renamed_by_date\63.jpg como tmp\images\200_images_processed\62.jpg
# Copiado: tmp\images\100_images_renamed_by_date\64.jpg como tmp\images\200_images_processed\63.jpg
# Copiado: tmp\images\100_images_renamed_by_date\65.jpg como tmp\images\200_images_processed\64.jpg
# Copiado: tmp\images\100_images_renamed_by_date\66.jpg como tmp\images\200_images_processed\65.jpg
# Copiado: tmp\images\100_images_renamed_by_date\67.jpg como tmp\images\200_images_processed\66.jpg
# Copiado: tmp\images\100_images_renamed_by_date\68.jpg como tmp\images\200_images_processed\67.jpg
# Copiado: tmp\images\100_images_renamed_by_date\69.jpg como tmp\images\200_images_processed\68.jpg
# Copiado: tmp\images\100_images_renamed_by_date\70.jpg como tmp\images\200_images_processed\69.jpg
# Copiado: tmp\images\100_images_renamed_by_date\71.jpg como tmp\images\200_images_processed\70.jpg
# Copiado: tmp\images\100_images_renamed_by_date\72.jpg como tmp\images\200_images_processed\71.jpg
# Copiado: tmp\images\100_images_renamed_by_date\73.jpg como tmp\images\200_images_processed\72.jpg
# Copiado: tmp\images\100_images_renamed_by_date\74.jpg como tmp\images\200_images_processed\73.jpg
# Copiado: tmp\images\100_images_renamed_by_date\75.jpg como tmp\images\200_images_processed\74.jpg
# Copiado: tmp\images\100_images_renamed_by_date\76.jpg como tmp\images\200_images_processed\75.jpg
# Copiado: tmp\images\100_images_renamed_by_date\77.jpg como tmp\images\200_images_processed\76.jpg
# Copiado: tmp\images\100_images_renamed_by_date\78.jpg como tmp\images\200_images_processed\77.jpg
# Copiado: tmp\images\100_images_renamed_by_date\79.jpg como tmp\images\200_images_processed\78.jpg
# Copiado: tmp\images\100_images_renamed_by_date\80.jpg como tmp\images\200_images_processed\79.jpg
# Copiado: tmp\images\100_images_renamed_by_date\81.jpg como tmp\images\200_images_processed\80.jpg
# Copiado: tmp\images\100_images_renamed_by_date\82.jpg como tmp\images\200_images_processed\81.jpg
# Copiado: tmp\images\100_images_renamed_by_date\83.jpg como tmp\images\200_images_processed\82.jpg
# Copiado: tmp\images\100_images_renamed_by_date\84.jpg como tmp\images\200_images_processed\83.jpg
# Copiado: tmp\images\100_images_renamed_by_date\85.jpg como tmp\images\200_images_processed\84.jpg
# Copiado: tmp\images\100_images_renamed_by_date\86.jpg como tmp\images\200_images_processed\85.jpg
# Copiado: tmp\images\100_images_renamed_by_date\87.jpg como tmp\images\200_images_processed\86.jpg
# Copiado: tmp\images\100_images_renamed_by_date\88.jpg como tmp\images\200_images_processed\87.jpg
# Copiado: tmp\images\100_images_renamed_by_date\89.jpg como tmp\images\200_images_processed\88.jpg
# Copiado: tmp\images\100_images_renamed_by_date\90.jpg como tmp\images\200_images_processed\89.jpg
# Copiado: tmp\images\100_images_renamed_by_date\91.jpg como tmp\images\200_images_processed\90.jpg
# Copiado: tmp\images\100_images_renamed_by_date\92.jpg como tmp\images\200_images_processed\91.jpg
# Copiado: tmp\images\100_images_renamed_by_date\93.jpg como tmp\images\200_images_processed\92.jpg
# Total de imágenes copiadas: 92

# %% [markdown]
# Se une el archivo data con las coordenadas del gps

# %%
print(df.shape[0])
print(df_gps.shape[0])
df_union = pd.concat([df.reset_index(drop=True), df_gps.reset_index(drop=True)], axis=1)
# Out:
# 34
# 34

# %%
df_union.head()
# Out:
#    id tipo   descripcion informacion-adicional km m sentido  foto-number  \
# 0   1                fin                                  u          [1]
# 1   2       alcantarilla                                  u    [3, 4, 5]
# 2   3              baden                                  u          [7]
# 3   4       alcantarilla                                  u  [9, 10, 11]
# 4   5       alcantarilla                                  u     [13, 14]
#
#   foto-gps observacion observacion-detalles observacion-gabinete       x  \
# 0      [2]                                                        189967
# 1      [6]                                                        189968
# 2      [8]                                       foto 7 repetida  190139
# 3     [12]                                                        190105
# 4     [15]                                                        190092
#
#          y  zona
# 0  8229889    19
# 1  8229891    19
# 2  8227888    19
# 3  8227713    19
# 4  8227457    19

# %% [markdown]
# Visualizamos el archivo final para exportarlo

# %%
html = df_union.to_html()
display(HTML(html))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>tipo</th>
#       <th>descripcion</th>
#       <th>informacion-adicional</th>
#       <th>km</th>
#       <th>m</th>
#       <th>sentido</th>
#       <th>foto-number</th>
#       <th>foto-gps</th>
#       <th>observacion</th>
#       <th>observacion-detalles</th>
#       <th>observacion-gabinete</th>
#       <th>x</th>
#       <th>y</th>
#       <th>zona</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td></td>
#       <td>fin</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[1]</td>
#       <td>[2]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>189967</td>
#       <td>8229889</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[3, 4, 5]</td>
#       <td>[6]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>189968</td>
#       <td>8229891</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td></td>
#       <td>baden</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[7]</td>
#       <td>[8]</td>
#       <td></td>
#       <td></td>
#       <td>foto 7 repetida</td>
#       <td>190139</td>
#       <td>8227888</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[9, 10, 11]</td>
#       <td>[12]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190105</td>
#       <td>8227713</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[13, 14]</td>
#       <td>[15]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190092</td>
#       <td>8227457</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>a</td>
#       <td>señal de baden</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>o</td>
#       <td>[16]</td>
#       <td>[17]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190127</td>
#       <td>8227358</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td></td>
#       <td>baden</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[18]</td>
#       <td>[19]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190141</td>
#       <td>8227320</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>a</td>
#       <td>señal de baden</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>i</td>
#       <td>[20]</td>
#       <td>[21]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190143</td>
#       <td>8227283</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>a</td>
#       <td>curva</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>o</td>
#       <td>[22]</td>
#       <td>[23]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190145</td>
#       <td>8227246</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[24, 25, 26]</td>
#       <td>[27]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190165</td>
#       <td>8227209</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>11</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[28, 29]</td>
#       <td>[30]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190169</td>
#       <td>8227204</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>12</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[31, 32]</td>
#       <td>[33]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190197</td>
#       <td>8227112</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[34, 35, 36]</td>
#       <td>[37]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190179</td>
#       <td>8227013</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>14</td>
#       <td></td>
#       <td>curva y contracurva pronunciada</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>[38]</td>
#       <td>[39]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190191</td>
#       <td>8226955</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>15</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[40, 41, 42]</td>
#       <td>[43]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190224</td>
#       <td>8226853</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>16</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[44, 45, 46]</td>
#       <td>[47]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190233</td>
#       <td>8226811</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>17</td>
#       <td>a</td>
#       <td>señal de puente angosto</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>[48]</td>
#       <td>[49]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190210</td>
#       <td>8226664</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>18</td>
#       <td></td>
#       <td>puente</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[50]</td>
#       <td>[51]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190223</td>
#       <td>8226628</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>19</td>
#       <td></td>
#       <td>señal de puente angosto</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>i</td>
#       <td>[52]</td>
#       <td>[53]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190241</td>
#       <td>8226599</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>20</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[54, 55, 56]</td>
#       <td>[57]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190472</td>
#       <td>8226397</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>21</td>
#       <td></td>
#       <td>curva y contracurva pronunciada</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>[58]</td>
#       <td>[59]</td>
#       <td>deterioro severo</td>
#       <td>señal borrada</td>
#       <td></td>
#       <td>190530</td>
#       <td>8226405</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>22</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[60, 61, 62]</td>
#       <td>[63]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190610</td>
#       <td>8226503</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>23</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>u</td>
#       <td>[64, 65]</td>
#       <td>[66]</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>190948</td>
#       <td>8226365</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>24</td>
#       <td></td>
#       <td>alcantarilla</td>
#       <td></td>
#       <td></td>
#       <td></td>

# %% [markdown]
# ## Se guarda la data procesada en un archivo pickle

# %%
df.to_pickle(processed_data_pickle_path)
